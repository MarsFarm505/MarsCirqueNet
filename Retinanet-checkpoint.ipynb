# %%
# !python keras-retinanet\keras_retinanet\bin\train.py \
--weights keras-retinanet\snapshots\model.h5 \
--batch-size 4 \
--random-transform \
--epochs 20 \
--steps 398 \
--lr 1e-5 \
--tensorboard-dir log \
csv train-new.csv classes.csv \
--val-annotations val-new.csv
# Out:
# Creating model, this may take a second...
# Model: "retinanet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python keras-retinanet\keras_retinanet\bin\convert_model.py snapshots\resnet50_csv_08.h5 snapshots\model_infrence.h5
# Out:
# 2023-01-13 16:29:32.717636: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Public\anaconda\envs\tf_env\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
ls keras-retinanet\keras_retinanet\bin\
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C4AC-F89A
#
#  Directory of C:\Users\Josh Williams\Retinanet\TrainingNew\keras-retinanet\keras_retinanet\bin
#
# 09/03/2022  02:24 PM    <DIR>          .
# 09/03/2022  02:24 PM    <DIR>          ..
# 09/03/2022  02:20 PM                 0 __init__.py
# 09/03/2022  02:24 PM    <DIR>          __pycache__
# 09/03/2022  02:20 PM             3,921 convert_model.py
# 09/03/2022  02:20 PM            13,799 debug.py
# 09/03/2022  02:20 PM             8,838 evaluate.py
# 09/03/2022  02:20 PM            24,288 train.py
#                5 File(s)         50,846 bytes
#                3 Dir(s)  232,933,888,000 bytes free

# %%
# !tensorboard  --logdir log
